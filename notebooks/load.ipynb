# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join('..')))

from src.load_raw_to_postgres import run_loader

result = run_loader()

print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       2 import sys
#       4 sys.path.append(os.path.abspath(os.path.join('..')))
# ----> 6 from src.load_raw_to_postgres import run_loader
#       8 result = run_loader()
#      10 print(result)
#
# File c:\Users\user\Desktop\Raw-Telegram-Data-to-an-Analytical-API\src\load_raw_to_postgres.py:16
#      14     psycopg2 = importlib.import_module("psycopg")
#      15 else:
# ---> 16     raise ImportError(
#      17         "neither 'psycopg2' nor 'psycopg' is installed; install one with "
#      18         "'pip install psycopg2-binary' or 'pip install psycopg'"
#      19     )
#      21 load_dotenv()
#      23 DB_CONFIG = {
#      24     "host": os.getenv("POSTGRES_HOST", "localhost"),
#      25     "port": os.getenv("POSTGRES_PORT", "5432"),
#    (...)     28     "password": os.getenv("postgres"),
#      29 }
# ...
